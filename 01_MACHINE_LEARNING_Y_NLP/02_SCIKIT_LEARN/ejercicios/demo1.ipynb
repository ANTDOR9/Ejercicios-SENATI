# %%
import pandas as pd
from sqlalchemy import create_engine
user='postgres'
password='123'
host='10.0.222.18'
port='5432'
database='tallerdb'

# %%
engine= create_engine(f"postgresql+psycopg2://{user}:{password}@{host}:{port}/{database}")
sql="select * from familia"
familia= pd.read_sql(sql, engine)
print (familia)
# Out:
#    idfamilia   nombre          descripcion
# 0          1  Bebidas   Todo sobre bebidas
# 1          2  Lácteos   Todo sobre lácteos
# 2          3  Escolar  Productos escolares

# %%
sql="select * from categoria"
categoria= pd.read_sql(sql, engine)
print (categoria)
# Out:
#    idcategoria        nombre  idfamilia
# 0            1       Gaseosa          1
# 1            2  Agua Mineral          1
# 2            3         Leche          2
# 3            4         Queso          2

# %%
vista_categorias = categoria.merge(familia, how='inner', on='idfamilia')
vista_categorias = vista_categorias.rename(columns={'nombre_x':'categoria','nombre_y':'familia'})
print(vista_categorias)
# Out:
#    idcategoria     categoria  idfamilia  familia         descripcion
# 0            1       Gaseosa          1  Bebidas  Todo sobre bebidas
# 1            2  Agua Mineral          1  Bebidas  Todo sobre bebidas
# 2            3         Leche          2  Lácteos  Todo sobre lácteos
# 3            4         Queso          2  Lácteos  Todo sobre lácteos

# %%
vista_resumen_categorias= vista_categorias[['categoria','familia']]
print(vista_resumen_categorias)  

print(vista_resumen_categorias.groupby('familia')['categoria'].count())
# Out:
#       categoria  familia
# 0       Gaseosa  Bebidas
# 1  Agua Mineral  Bebidas
# 2         Leche  Lácteos
# 3         Queso  Lácteos
# familia
# Bebidas    2
# Lácteos    2
# Name: categoria, dtype: int64

# %%
vista_categorias.pivot_table(index='categoria', columns='familia', aggfunc='size', fill_value=0)
# Out:
# familia       Bebidas  Lácteos
# categoria
# Agua Mineral        1        0
# Gaseosa             1        0
# Leche               0        1
# Queso               0        1
