# %% [markdown]
# # 02 · Regresión con TensorFlow/Keras
#
# ## Objetivo
# Entender cómo una red neuronal puede predecir un **valor numérico continuo**, en vez de una categoría. (acutlaizado)
#
# ## Teoría: clasificación vs. regresión
#
# | | Clasificación | Regresión |
# |---|---|---|
# | ¿Qué predice? | Una categoría (0/1, spam/no spam) | Un número continuo (precio, temperatura) |
# | Activación de salida típica | sigmoid (2 clases) o softmax (varias) | linear (sin restricción de rango) |
# | Función de pérdida típica | binary_crossentropy / categorical_crossentropy | mse (error cuadrático medio) |
#
# En este notebook vamos a enseñarle a la red la relación **Y = 3X** (la tabla del 3), para ver si logra "descubrir" esa fórmula solo mirando ejemplos.

# %% [markdown]
# ## Paso 1: Importar librerías
#
# Igual que en el notebook anterior: TensorFlow para el modelo, NumPy para los datos.

# %%
import tensorflow as tf
import numpy as np

# %% [markdown]
# ## Paso 2: Preparar los datos
#
# Usamos la tabla del 3: si X=1, Y=3; si X=2, Y=6; y así sucesivamente. La idea es que el modelo aprenda la relación **Y = 3·X** solo con estos ejemplos, sin que le digamos la fórmula directamente.

# %%
X = np.array([[1], [2], [3], [4], [5], [6]])
Y = np.array([3, 6, 9, 12, 15, 18])

print("X:", X.flatten())
print("Y:", Y)
# Out:
# X: [1 2 3 4 5 6]
# Y: [ 3  6  9 12 15 18]

# %% [markdown]
# ## Paso 3: Construir la arquitectura
#
# Diferencias clave respecto al notebook de clasificación:
#
# - La capa oculta ahora tiene **4 neuronas** con ReLU (más capacidad que el ejemplo anterior, aunque el problema es simple).
# - La capa de salida usa activación **"linear"**: significa que NO se aplica ninguna función de activación extra, la neurona entrega directamente el valor `Z = ΣXᵢWᵢ + b`. Esto es necesario en regresión porque el valor a predecir puede ser cualquier número, no solo algo entre 0 y 1.

# %%
modelo = tf.keras.Sequential([
    tf.keras.layers.Dense(4, activation="relu", input_shape=(1,)),
    tf.keras.layers.Dense(1, activation="linear")  # regresión: sin restricción de rango
])

modelo.summary()
# Out:
# c:\Users\ANT DOR\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 4)              │             8 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             5 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13 (52.00 B)
# ...

# %% [markdown]
# ## Paso 4: Compilar
#
# - **optimizer="sgd"** (Stochastic Gradient Descent): un optimizador más simple y "clásico" que Adam, bueno para ver el aprendizaje de forma más gradual.
# - **loss="mse"** (Mean Squared Error / error cuadrático medio): mide el promedio de (predicción − valor real)² . Es la pérdida estándar para regresión, porque penaliza más los errores grandes.

# %%
modelo.compile(optimizer="sgd", loss="mse")
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %% [markdown]
# ## Paso 5: Entrenar
#
# Usamos más épocas (80) porque SGD suele necesitar más pasadas que Adam para converger.

# %%
historial = modelo.fit(X, Y, epochs=80, verbose=0)
print("Pérdida (mse) final:", historial.history["loss"][-1])
# Out:
# Pérdida (mse) final: 0.007828814908862114

# %% [markdown]
# ## Paso 6: Predecir
#
# Probamos con X=10. Si el modelo aprendió bien la relación Y=3X, la predicción debería acercarse a 30.

# %%
prediccion = modelo.predict(np.array([[10]]))
print("Predicción para X=10 (esperado ≈30):", prediccion)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Predicción para X=10 (esperado ≈30): [[29.736095]]

# %% [markdown]
# ## Conclusión del notebook
#
# - La diferencia técnica clave entre clasificar y hacer regresión está en la **capa de salida**: sigmoid/softmax para clasificar, linear para regresión.
# - También cambia la **función de pérdida**: crossentropy para clasificar, mse para regresión.
# - El resto del flujo (armar el modelo, compilar, entrenar, predecir) es idéntico.
